# %% [markdown]
# Write a Python program that reads in 3 integers or 4 integers (user first determines 3 or 4 integers) and displays the following:
#
# a.	the average of the numbers (two decimal places suggested)
# b.	the maximum of the numbers
# c.	the minimum of the numbers
# d.	the median of the numbers. Note that if there was 2 numbers that qualify for the median, you will calculate and display the mean of the 2 numbers
#
# Do NOT use statistical functions such as mean(), median(), max() or min(). You will not receive credit for the question if you do so.
# 	 	A sample run is shown below:
# Enter set of 3 or 4 integers: 3
# Enter first number: 7
# Enter second number: 10
# Enter third number: 1
# The average of 7, 10 and 1 is: 6.0
# The maximum of the three numbers is:  10
# The minimum of the three numbers is: 1
# The median of the three numbers is: 7
#
# Enter set of 3 or 4 integers: 4
# Enter first number: 7
# Enter second number: 10
# Enter third number: 1
# Enter fourth number: 6
# The average of 7, 10 ,1 and 6 is: 6.0
# The maximum of the four numbers is:  10
# The minimum of the four numbers is: 1
# The median of the four numbers is: 6.5

# %%
totalInteger = 0
average = 0.0
maximum = 0
minimum = 0
median = 0

firstInteger = secondInteger = thirdInteger = fourthInteger = 0

while not int(totalInteger) in range(3,5) :
    # print( type(totalInteger) )
    # print( type(average) )
    totalInteger = int(input("Enter set of 3 or 4 integers: "))
# print( totalInteger )
# print( type(totalInteger) )

if int(totalInteger) == 3 :
    firstInteger = int(input('Enter first number:'))
    secondInteger = int(input('Enter second number:'))
    thirdInteger = int(input('Enter third number:'))
    average = (firstInteger + secondInteger + thirdInteger) / (totalInteger)
    

    #Finding maximum number
    if (firstInteger > thirdInteger) and (firstInteger > secondInteger):
        maximum = firstInteger
    elif(secondInteger > thirdInteger ) and (secondInteger > firstInteger ) :
        maximum = secondInteger
    else: 
        maximum = thirdInteger
    
    #Finding minimum number
    if (firstInteger < thirdInteger) and (firstInteger < secondInteger):
        minimum = firstInteger
    elif(secondInteger < thirdInteger ) and (secondInteger < firstInteger ) :
        minimum = secondInteger
    else: 
        minimum = thirdInteger
    
    #Finding median 
    if firstInteger > secondInteger:
        if firstInteger < thirdInteger :
            median = firstInteger
        elif secondInteger > thirdInteger :
            median = secondInteger
        else:
            median = thirdInteger
    else:
        if firstInteger > thirdInteger:
            median = firstInteger
        elif secondInteger < thirdInteger:
            median = secondInteger
        else:
            median = thirdInteger
            
    print('The average of ' , firstInteger, ',' ,  secondInteger, ','  , thirdInteger , 'is: ' , average)
    print('The maximum of the three numbers is:',  maximum )
    print('The minimum of the three numbers is:',  minimum )      
    print('The median of the three numbers is:', median)      

else :
    #decalring empty list
    integerList = []
    ascendingList = []
    
    #getting input from user
    firstInteger = int(input('Enter first number:'))
    secondInteger = int(input('Enter second number:'))
    thirdInteger = int(input('Enter third number:'))
    fourthInteger = int(input('Enter fourth number:'))
        

    #pushing user input to list
    integerList.append(firstInteger)
    integerList.append(secondInteger)
    integerList.append(thirdInteger)
    integerList.append(fourthInteger)


    maximum = minimum = integerList[0]
    #finding max number from list
    # print(integerList)
    length = len(integerList)
    for i in range(length): 
        # print(integerList[i])
        if integerList[i] > maximum:
            maximum = integerList[i]
      
      #finding minimum number from list
    for j in range(length):
        if (integerList[j] < minimum):
            minimum = integerList[j]

      #cloning first list to an empty list to sort it
    ascendingList = integerList.copy()
      #sorting list into ascending order
    for i in range (length):
        for j in range(i + 1, length):
            if(ascendingList[i] > ascendingList[j]):
                temp = ascendingList[i]
                ascendingList[i] = ascendingList[j]
                ascendingList[j] = temp

      #finding median from the list 
    median = (ascendingList[1] + ascendingList[2]) / 2
     # print("Element Before Sorting List in Ascending Order is : ", integerList)
    # print("Element After Sorting List in Ascending Order is : ", ascendingList)
    average = ((firstInteger + secondInteger + thirdInteger + fourthInteger) / totalInteger)
    print('The average of ', firstInteger, ',' , secondInteger, ',' , thirdInteger , ',' , fourthInteger, ',' , 'is: ' , average)
    print('The maximum of the four numbers is:',  maximum)
    print('The minimum of the four numbers is:',  minimum)
    print('The median of the three numbers is:', median)
# Out:
# Enter set of 3 or 4 integers: 4
# Enter first number:1
# Enter second number:23
# Enter third number:45
# Enter fourth number:6
# The average of  1 , 23 , 45 , 6 , is:  18.75
# The maximum of the four numbers is: 45
# The minimum of the four numbers is: 1
# The median of the three numbers is: 14.5
